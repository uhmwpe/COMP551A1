# %%
import pandas as pd
import re 
import sys

df = pd.read_csv(sys.argv[1])

# %%
df.iloc[2].user
df.drop('replies.id', axis=1, inplace=True)
df.drop('replies.date', axis=1, inplace=True)
df.drop('replies.timestamp', axis=1, inplace=True)
df.drop('replies.likes', axis=1, inplace=True)
df.drop('id', axis=1, inplace=True)
df.drop('timestamp', axis=1, inplace=True)
df.drop('likes', axis=1, inplace=True)
df.drop('date', axis=1, inplace=True)

df.rename(columns={'replies.commentText': 'repliesCommentText', 'replies.user': 'repliesUser'}, inplace=True)

# %%
if (sys.argv[2] == True):
    f = open('youtubeComments.xml', 'w')
    f.write('<dialogue> \n')
    f.close()

# %%
df['commentText'].str.replace(r"IsHan","")
df
# Out:
#                     user                                        commentText  \
# 0            Shawn Great  so good ,  im so happy I  find you sing this s...
# 1                    李學豪                                            很有感觸 謝謝
# 2                    王姿阿                                        聽第一段，直接訂閱了😜
# 3                    NaN                                                NaN
# 4                    衛胤黎                                                好聽!
# 5                    NaN                                                NaN
# 6                    林其緯                                             有吉他的譜嗎
# 7                    NaN                                                NaN
# 8                    邱小樂                                                好聽~
# 9                    NaN                                                NaN
# 10          BONjour lele                                         好舒服的歌聲，超好聽
# 11                   NaN                                                NaN
# 12                   潘家翔                               唱出了我的心情   聽你唱得歌  好舒服
# 13                   NaN                                                NaN
# 14                   董寶慶                               如果能讓我再重新選擇一次，我會選擇不婚。
# 15                   NaN                                                NaN
# 16                   NaN                                                NaN
# 17                   NaN                                                NaN
# 18                   NaN                                                NaN
# 19                   蔡育廷                                   真的好好聽 很療癒很有溫度的聲音
# 20                   NaN                                                NaN
# 21                  沐月 王                                            发音已经很标准
# 22                   NaN                                                NaN
# 23           洪小協 hzpty08                                         想聽妳的聲音唱鄭中基
# 24                   NaN                                                NaN
# 25            Waijun Foo                                             这歌声真是👍
# 26                   NaN                                                NaN
# 27                   曾憲巍                                               非常喜歡
# 28                   NaN                                                NaN
# 29                   NaN                                                NaN
# ...                  ...                                                ...
# 972                  NaN                                                NaN
# 973             KKwok320                                         很好聽! 繼續加油!
# 974                  NaN                                                NaN
# 975             Chaio Lo                                            很喜歡很好聽…
# 976                  NaN                                                NaN
# 977                A TZY                                         so nice!!!
# 978                  NaN                                                NaN
# 979                    為                                               聲音真好
# 980                  NaN                                                NaN
# 981                  崇瑋廖                                                 好聽
# 982                  NaN                                                NaN
# 983         Brandon Wong  從超偶的海闊天空，到今天的你。。。你變了的部分是聲音更加細膩，沒有變的部分是你的真。這種《真...
# 984                  NaN                                                NaN
# 985   Chutiphorn Saewang                                       好好聽 我是你的泰粉喲😍
# 986                  NaN                                                NaN
# 987                  康芷芸                        今天一直哼著這首歌~沒想到剛好就聽到這麼棒的cover
# 988                  NaN                                                NaN
# 989             Emily Wu                                           超喜歡你的聲音~
# 990                  NaN                                                NaN
# 991                  NaN                                                NaN
# 992                Sa Sa                             你聲音就是會讓我停下手邊工作轉身的人，加油!
# 993                  NaN                                                NaN
# 994                  NaN                                                NaN
# 995                  NaN                                                NaN
# 996                  黃于勛                                              讚RRRR
# 997                  NaN                                                NaN
# 998            Guojhu. C                                     太喜歡你的聲音!!!!!!!
# 999                  NaN                                                NaN
# 1000                 蕭詩婷                                        太棒惹( ´▽` )ﾉ
# 1001                 NaN                                                NaN
#
#      hasReplies  numberOfReplies   repliesUser  \
# 0         False              0.0           NaN
# 1         False              0.0           NaN
# 2          True              1.0           NaN
# 3           NaN              NaN  吳海文 Kevin Wu
# 4          True              1.0           NaN
# 5           NaN              NaN  吳海文 Kevin Wu
# 6          True              1.0           NaN
# 7           NaN              NaN  吳海文 Kevin Wu
# 8          True              1.0           NaN
# 9           NaN              NaN  吳海文 Kevin Wu
# 10         True              1.0           NaN
# 11          NaN              NaN  吳海文 Kevin Wu
# 12         True              1.0           NaN
# 13          NaN              NaN  吳海文 Kevin Wu
# 14         True              4.0           NaN
# 15          NaN              NaN  吳海文 Kevin Wu
# 16          NaN              NaN           董寶慶
# 17          NaN              NaN  吳海文 Kevin Wu
# 18          NaN              NaN           董寶慶
# 19         True              1.0           NaN
# 20          NaN              NaN  吳海文 Kevin Wu
# 21         True              1.0           NaN
# 22          NaN              NaN  吳海文 Kevin Wu
# 23         True              1.0           NaN
# 24          NaN              NaN  吳海文 Kevin Wu
# 25         True              1.0           NaN
# 26          NaN              NaN  吳海文 Kevin Wu
# 27         True              2.0           NaN
# 28          NaN              NaN  吳海文 Kevin Wu
# 29          NaN              NaN           曾憲巍
# ...         ...              ...           ...
# 972         NaN              NaN  吳海文 Kevin Wu
# 973        True              1.0           NaN
# 974         NaN              NaN  吳海文 Kevin Wu
# 975        True              1.0           NaN
# 976         NaN              NaN  吳海文 Kevin Wu
# 977        True              1.0           NaN
# 978         NaN              NaN  吳海文 Kevin Wu
# 979        True              1.0           NaN
# 980         NaN              NaN  吳海文 Kevin Wu
# 981        True              1.0           NaN
# 982         NaN              NaN  吳海文 Kevin Wu
# 983        True              1.0           NaN
# 984         NaN              NaN  吳海文 Kevin Wu
# 985        True              1.0           NaN
# 986         NaN              NaN  吳海文 Kevin Wu
# 987        True              1.0           NaN
# 988         NaN              NaN  吳海文 Kevin Wu
# 989        True              2.0           NaN
# 990         NaN              NaN  吳海文 Kevin Wu
# 991         NaN              NaN      Tiger Wu
# 992        True              3.0           NaN
# 993         NaN              NaN  吳海文 Kevin Wu
# 994         NaN              NaN           彭小白
# 995         NaN              NaN        lion 張
# 996        True              1.0           NaN
# 997         NaN              NaN  吳海文 Kevin Wu
# 998        True              1.0           NaN
# 999         NaN              NaN  吳海文 Kevin Wu
# 1000       True              1.0           NaN
# 1001        NaN              NaN  吳海文 Kevin Wu
#
#                             repliesCommentText
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                     這個決定是對的😆
# 4                                          NaN
# 5                                         謝謝🙌🏻
# 6                                          NaN
# 7                                          沒有😂
# 8                                          NaN
# 9                                       謝謝支持🙌🏻
# 10                                         NaN
# 11                                那怎麼能不訂閱呢？🙈❤️
# 12                                         NaN
# 13                                          ❤️
# 14                                         NaN
# 15                                          ☹️
# 16                   海文~SORRY~讓你擔心了，你放心，我為母則強。
# 17                                     董寶慶 加油🌹
# 18                                     THANKS!
# 19                                         NaN
# 20                                也介紹給你朋友聽吧 ❤️
# 21                                         NaN
# 22                                        謝謝老師
# 23                                         NaN
# 24                               何必跟我 我這種無賴~~😆
# 25                                         NaN
# 26                                      你要分享哦😆
# 27                                         NaN
# 28                                       謝謝市長🌹
# 29             吳海文 Kevin Wu 哈哈哈謝謝你的回覆\n你很幽默餒哈哈
# ...                                        ...
# 972                        哇！其實我覺得我這次可以再更好一點><
# 973                                        NaN
# 974                                 好der！謝謝支持😁
# 975                                        NaN
# 976                                        謝謝😀
# 977                                        NaN
# 978                                  Thanks ☺️
# 979                                        NaN
# 980                                        謝謝😁
# 981                                        NaN
# 982                                        謝謝😁
# 983                                        NaN
# 984                    謝謝你那麼細微的觀察，還望你之後多多幫忙分享😁
# 985                                        NaN
# 986                                泰粉你好，我是米粉哈哈
# 987                                        NaN
# 988                                  不敢不敢，有待改進
# 989                                        NaN
# 990                                      感謝支持😁
# 991                                     那英－夢一場
# 992                                        NaN
# 993                                 這評價很高，謝謝你！
# 994   想聽這個歌的時候，我會把遊戲的音源關閉~\n\n尤其半夜的時候~~這聲音令人平靜
# 995                                     真的!!!!
# 996                                        NaN
# 997                                        謝謝😁
# 998                                        NaN
# 999                                        謝謝😀
# 1000                                       NaN
# 1001                                       謝謝😁
#
# [1002 rows x 6 columns]

# %%
import re
for n in re.findall(r'[^\u4e00-\u9fff，。／【】、；‘:""]+',df.iloc[2].commentText):
    print (n)
# Out:
# 😜

# %%
df['commentText'] = df['commentText'].str.replace(r"[^\u4e00-\u9fff，。／【】、；‘:""]+","")
df['repliesCommentText'] = df['repliesCommentText'].str.replace(r"[^\u4e00-\u9fff，。／【】、；‘:""]+","")

# %%
df = df[df.commentText != '']
df = df[df.repliesCommentText != '']
df = df.reset_index()
df
# Out:
#      index                user  \
# 0        1                 李學豪
# 1        2                 王姿阿
# 2        3                 NaN
# 3        4                 衛胤黎
# 4        5                 NaN
# 5        6                 林其緯
# 6        7                 NaN
# 7        8                 邱小樂
# 8        9                 NaN
# 9       10        BONjour lele
# 10      11                 NaN
# 11      12                 潘家翔
# 12      14                 董寶慶
# 13      16                 NaN
# 14      17                 NaN
# 15      19                 蔡育廷
# 16      20                 NaN
# 17      21                沐月 王
# 18      22                 NaN
# 19      23         洪小協 hzpty08
# 20      24                 NaN
# 21      25          Waijun Foo
# 22      26                 NaN
# 23      27                 曾憲巍
# 24      28                 NaN
# 25      29                 NaN
# 26      30          ke19911215
# 27      31                 NaN
# 28      32                  宇鋒
# 29      33                 NaN
# ..     ...                 ...
# 910    970                 NaN
# 911    971           Chiao Chu
# 912    972                 NaN
# 913    973            KKwok320
# 914    974                 NaN
# 915    975            Chaio Lo
# 916    976                 NaN
# 917    979                   為
# 918    980                 NaN
# 919    981                 崇瑋廖
# 920    982                 NaN
# 921    983        Brandon Wong
# 922    984                 NaN
# 923    985  Chutiphorn Saewang
# 924    986                 NaN
# 925    987                 康芷芸
# 926    988                 NaN
# 927    989            Emily Wu
# 928    990                 NaN
# 929    991                 NaN
# 930    992               Sa Sa
# 931    993                 NaN
# 932    994                 NaN
# 933    995                 NaN
# 934    996                 黃于勛
# 935    997                 NaN
# 936    998           Guojhu. C
# 937    999                 NaN
# 938   1000                 蕭詩婷
# 939   1001                 NaN
#
#                                            commentText hasReplies  \
# 0                                               很有感觸謝謝      False
# 1                                           聽第一段，直接訂閱了       True
# 2                                                  NaN        NaN
# 3                                                   好聽       True
# 4                                                  NaN        NaN
# 5                                               有吉他的譜嗎       True
# 6                                                  NaN        NaN
# 7                                                   好聽       True
# 8                                                  NaN        NaN
# 9                                           好舒服的歌聲，超好聽       True
# 10                                                 NaN        NaN
# 11                                     唱出了我的心情聽你唱得歌好舒服       True
# 12                                如果能讓我再重新選擇一次，我會選擇不婚。       True
# 13                                                 NaN        NaN
# 14                                                 NaN        NaN
# 15                                     真的好好聽很療癒很有溫度的聲音       True
# 16                                                 NaN        NaN
# 17                                             发音已经很标准       True
# 18                                                 NaN        NaN
# 19                                          想聽妳的聲音唱鄭中基       True
# 20                                                 NaN        NaN
# 21                                               这歌声真是       True
# 22                                                 NaN        NaN
# 23                                                非常喜歡       True
# 24                                                 NaN        NaN
# 25                                                 NaN        NaN
# 26                                                 異鄉人       True
# 27                                                 NaN        NaN
# 28                                          超好聽好像比原場好聽       True
# 29                                                 NaN        NaN
# ..                                                 ...        ...
# 910                                                NaN        NaN
# 911                     沉浸在你所有富帶感情的溫柔詮釋覺得很幸運地沒有錯過你的好聲音       True
# 912                                                NaN        NaN
# 913                                            很好聽繼續加油       True
# 914                                                NaN        NaN
# 915                                             很喜歡很好聽       True
# 916                                                NaN        NaN
# 917                                               聲音真好       True
# 918                                                NaN        NaN
# 919                                                 好聽       True
# 920                                                NaN        NaN
# 921  從超偶的海闊天空，到今天的你。。。你變了的部分是聲音更加細膩，沒有變的部分是你的真。這種真是...       True
# 922                                                NaN        NaN
# 923                                         好好聽我是你的泰粉喲       True
# 924                                                NaN        NaN
# 925                              今天一直哼著這首歌沒想到剛好就聽到這麼棒的       True
# 926                                                NaN        NaN
# 927                                            超喜歡你的聲音       True
# 928                                                NaN        NaN
# 929                                                NaN        NaN
# 930                              你聲音就是會讓我停下手邊工作轉身的人，加油       True
# 931                                                NaN        NaN
# 932                                                NaN        NaN
# 933                                                NaN        NaN
# 934                                                  讚       True
# 935                                                NaN        NaN
# 936                                            太喜歡你的聲音       True
# 937                                                NaN        NaN
# 938                                                太棒惹       True
# 939                                                NaN        NaN
#
#      numberOfReplies   repliesUser                 repliesCommentText
# 0                0.0           NaN                                NaN
# 1                1.0           NaN                                NaN
# 2                NaN  吳海文 Kevin Wu                            這個決定是對的
# 3                1.0           NaN                                NaN
# 4                NaN  吳海文 Kevin Wu                                 謝謝
# 5                1.0           NaN                                NaN
# 6                NaN  吳海文 Kevin Wu                                 沒有
# 7                1.0           NaN                                NaN
# 8                NaN  吳海文 Kevin Wu                               謝謝支持
# 9                1.0           NaN                                NaN
# 10               NaN  吳海文 Kevin Wu                           那怎麼能不訂閱呢
# 11               1.0           NaN                                NaN
# 12               4.0           NaN                                NaN
# 13               NaN           董寶慶                 海文讓你擔心了，你放心，我為母則強。
# 14               NaN  吳海文 Kevin Wu                              董寶慶加油
# 15               1.0           NaN                                NaN
# 16               NaN  吳海文 Kevin Wu                          也介紹給你朋友聽吧
# 17               1.0           NaN                                NaN
# 18               NaN  吳海文 Kevin Wu                               謝謝老師
# 19               1.0           NaN                                NaN
# 20               NaN  吳海文 Kevin Wu                          何必跟我我這種無賴
# 21               1.0           NaN                                NaN
# 22               NaN  吳海文 Kevin Wu                              你要分享哦
# 23               2.0           NaN                                NaN
# 24               NaN  吳海文 Kevin Wu                               謝謝市長
# 25               NaN           曾憲巍                吳海文哈哈哈謝謝你的回覆你很幽默餒哈哈
# 26               1.0           NaN                                NaN
# 27               NaN  吳海文 Kevin Wu                           我是啊我來自異鄉
# 28               1.0           NaN                                NaN
# 29               NaN  吳海文 Kevin Wu                       希望你這樣說完我不會被黑
# ..               ...           ...                                ...
# 910              NaN  吳海文 Kevin Wu                              劉士華謝謝
# 911              1.0           NaN                                NaN
# 912              NaN  吳海文 Kevin Wu                   哇其實我覺得我這次可以再更好一點
# 913              1.0           NaN                                NaN
# 914              NaN  吳海文 Kevin Wu                              好謝謝支持
# 915              1.0           NaN                                NaN
# 916              NaN  吳海文 Kevin Wu                                 謝謝
# 917              1.0           NaN                                NaN
# 918              NaN  吳海文 Kevin Wu                                 謝謝
# 919              1.0           NaN                                NaN
# 920              NaN  吳海文 Kevin Wu                                 謝謝
# 921              1.0           NaN                                NaN
# 922              NaN  吳海文 Kevin Wu             謝謝你那麼細微的觀察，還望你之後多多幫忙分享
# 923              1.0           NaN                                NaN
# 924              NaN  吳海文 Kevin Wu                        泰粉你好，我是米粉哈哈
# 925              1.0           NaN                                NaN
# 926              NaN  吳海文 Kevin Wu                          不敢不敢，有待改進
# 927              2.0           NaN                                NaN
# 928              NaN  吳海文 Kevin Wu                               感謝支持
# 929              NaN      Tiger Wu                              那英夢一場
# 930              3.0           NaN                                NaN
# 931              NaN  吳海文 Kevin Wu                          這評價很高，謝謝你
# 932              NaN           彭小白  想聽這個歌的時候，我會把遊戲的音源關閉尤其半夜的時候這聲音令人平靜
# 933              NaN        lion 張                                 真的
# 934              1.0           NaN                                NaN
# 935              NaN  吳海文 Kevin Wu                                 謝謝
# 936              1.0           NaN                                NaN
# 937              NaN  吳海文 Kevin Wu                                 謝謝
# 938              1.0           NaN                                NaN
# 939              NaN  吳海文 Kevin Wu                                 謝謝
#
# [940 rows x 7 columns]

# %%
users = []

f = open('youtubeComments.xml', 'a')
for i in range(0, df.index.size-1):
    if (pd.isnull(df.iloc[i].user) == False) and (pd.isnull(df.iloc[i+1].user) == False): #deals with case where there are no replies
        uttid = 1
        s = '\t<s> \n'.expandtabs(4)
        s += '\t< utt uid=\"'.expandtabs(8)
        s += str(uttid)
        s += '\">'
        s += str(df.iloc[i].commentText)
        s += '</utt>\n'
        s+= '\t</s> \n'.expandtabs(4)
        f.write(s)
    elif (pd.isnull(df.iloc[i+1].user) == True) and (pd.isnull(df.iloc[i].user) == False):
        users = []
        users.append(df.iloc[i].user)
        uttid = 1
        s = '\t<s> \n'.expandtabs(4)
        s += '\t< utt uid=\"'.expandtabs(8)
        s += str(uttid)
        s += '\">'
        s += str(df.iloc[i].commentText)
        s += '</utt>\n'
        if (i<df.index.size - 1):
            j = i+1
            
        a = 0
        
        while((pd.isnull(df.iloc[j].user)==True) and (j<(df.index.size - 1))):
            if not (pd.isnull(df.iloc[j].user)):
                if df.iloc[j].user in users: #name already exists
                    a = a+1
                else:
                    users.append(df.iloc[j].user)
            else:
                if df.iloc[j].repliesUser in users:
                    a = a+1
                else:
                    users.append(df.iloc[j].repliesUser)
            uttid = users.index(df.iloc[j].repliesUser) + 1
            s += '\t< utt uid=\"'.expandtabs(8)
            s += str(uttid)
            s += '\">'
            s += df.iloc[j].repliesCommentText
            s += '</utt>\n'
            j += 1
            
           
        i = j
        s+= '\t</s> \n'.expandtabs(4)
        f.write(s)
            
        

f.close()

# %%
users
# Out:
# ['蕭詩婷']

# %%
df

# %%
if (sys.argv[3] == True):
    f = open('youtubeComments.xml', 'a')
    f.write('</dialogue>')
